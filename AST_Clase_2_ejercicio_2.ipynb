# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales - 2023</h1>
#     <h3>Clase 2</h3>
#     <h5>Ejercicio 2</h5>
#         <p>Docente: Rodrigo Del Rosso<p>
#         <p>Asistentes: Sebastián Calcagno y Braian Drago <p>
# </div>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA

import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=[10,7.5]

# %% [markdown]
# Simulamos un AR(2)

# %%
ar2=np.array([1,0.33,0.5])

# %%
AR2= ArmaProcess(ar2).generate_sample(nsample=1000)

# %%
plt.plot(AR2)
plt.title('Grafico de la serie original')
plt.xlim([0,200])
plt.show()

# %%
plot_acf(AR2);
plot_pacf(AR2);

# %% [markdown]
# Aqui vamos a trabajar con un modelo AR2

# %%
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

# %%
modeloAR2 = sm.tsa.arima.ARIMA(AR2, order=(2,0,0))
resultadosAR2 = modeloAR2.fit()

# %%
resultadosAR2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1440.507
# Date:                Tue, 10 Oct 2023   AIC                           2889.013
# Time:                        22:59:50   BIC                           2908.644
# Sample:                             0   HQIC                          2896.474
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0089      0.018     -0.504      0.614      -0.044       0.026
# ar.L1         -0.3451      0.028    -12.494      0.000      -0.399      -0.291
# ar.L2         -0.4853      0.028    -17.277      0.000      -0.540      -0.430
# sigma2         1.0435      0.046     22.716      0.000       0.953       1.133
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                 0.25
# Prob(Q):                              0.64   Prob(JB):                         0.88
# Heteroskedasticity (H):               1.20   Skew:                             0.02
# Prob(H) (two-sided):                  0.10   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
print(f"Los parametros del componente AR que arroja el modelo son= \n {resultadosAR2.polynomial_ar} ")
# Out:
# Los parametros del componente AR que arroja el modelo son=
#  [1.         0.34514844 0.48528567]
