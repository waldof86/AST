# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h1>Análisis de Series Temporales - 2023</h1>
#     <h3>Clase 2</h3>
#     <h5>Ejercicio 2</h5>
#         <p>Docente: Rodrigo Del Rosso<p>
#         <p>Asistentes: Sebastián Calcagno y Braian Drago <p>
# </div>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA

import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=[10,7.5]

# %% [markdown]
# Simulamos un AR(2)

# %%
ar2=np.array([1,0.33,0.5])

# %%
AR2= ArmaProcess(ar2).generate_sample(nsample=1000)

# %%
plt.plot(AR2)
plt.title('Grafico de la serie original')
plt.xlim([0,200])
plt.show()

# %%
plot_acf(AR2);
plot_pacf(AR2);

# %% [markdown]
# comentario 1

# %% [markdown]
# Aqui vamos a trabajar con un modelo AR2

# %%
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

# %%
modeloAR2 = sm.tsa.arima.ARIMA(AR2, order=(2,0,0))
resultadosAR2 = modeloAR2.fit()

# %%
resultadosAR2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -1385.206
# Date:                Mon, 28 Aug 2023   AIC                           2778.412
# Time:                        17:35:12   BIC                           2798.043
# Sample:                             0   HQIC                          2785.873
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0118      0.017     -0.701      0.483      -0.045       0.021
# ar.L1         -0.3136      0.028    -11.174      0.000      -0.369      -0.259
# ar.L2         -0.5091      0.028    -17.959      0.000      -0.565      -0.454
# sigma2         0.9342      0.042     22.503      0.000       0.853       1.016
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.04
# Prob(Q):                              0.92   Prob(JB):                         0.98
# Heteroskedasticity (H):               1.05   Skew:                             0.01
# Prob(H) (two-sided):                  0.68   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
print(f"Los parametros del componente AR que arroja el modelo son= \n {resultadosAR2.polynomial_ar} ")
# Out:
# array([1.        , 0.31358894, 0.50907022])
